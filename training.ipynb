# %% [markdown]
# # Import library dan modul yang diperlukan

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
import random

# %% [markdown]
# # Pra-Pemrosesan Data

# %%
# Inisialisasi objek lemmatizer untuk mengubah kata-kata menjadi bentuk dasar
lemmatizer = WordNetLemmatizer()

# Membaca data intents dari file JSON
data_file = open('data/intents.json').read()
intents = json.loads(data_file)

# Inisialisasi list untuk menyimpan kata-kata, kelas, dan dokumen
words = []
classes = []
documents = []
ignore_words = ['?', '!']

# Proses data intents untuk mendapatkan kata-kata, kelas, dan dokumen
for intent in intents['intents']:
    for pattern in intent['patterns']:
        
        # Tokenisasi setiap kata
        tokenized_words = nltk.word_tokenize(pattern)
        words.extend(tokenized_words)
        
        # Menambahkan dokumen ke dalam korpus
        documents.append((tokenized_words, intent['tag']))

        # Menambahkan kelas ke dalam list classes
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# Lemmatize dan ubah huruf kecil untuk setiap kata, dan hapus duplikat
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_words]
words = sorted(list(set(words)))

# Sortir kelas
classes = sorted(list(set(classes)))

# Menyimpan kata-kata dan kelas ke dalam file pickle
with open('texts.pkl', 'wb') as texts_file:
    pickle.dump(words, texts_file)
    
with open('labels.pkl', 'wb') as labels_file:
    pickle.dump(classes, labels_file)

with open('texts.pkl', 'rb') as text_file:
    texts_read = pickle.load(text_file)
    
with open('labels.pkl', 'rb') as label_file:
    labels_read = pickle.load(label_file)

    print(texts_read)
    print(labels_read)
# Out:
# ['/help', 'agar', 'aku', 'apa', 'apaan', 'babi', 'bagaimana', 'baiklah', 'bantu', 'bantuan', 'berobat', 'bertanya', 'bingung', 'bisa', 'boleh', 'bot', 'botdino', 'bye', 'cara', 'cegah', 'daah', 'dadah', 'dah', 'dawdawidjaiwldj', 'demam', 'diagnobot', 'diagnobott', 'diano', 'diare', 'dignobot', 'digobot', 'dinobot', 'diobatin', 'dong', 'emang', 'flu', 'gatal', 'gejala', 'hai', 'halo', 'help', 'hi', 'hidung', 'influenza', 'insomnia', 'itu', 'kabar', 'kak', 'kamu', 'kena', 'kepala', 'kerja', 'kesulitan', 'ketik', 'lo', 'lu', 'makasih', 'malam', 'mata', 'mau', 'mencegah', 'mencegahnya', 'merah', 'minta', 'monyet', 'nama', 'ngapain', 'obat', 'obatin', 'ok', 'p', 'pagi', 'pekerjaan', 'pengobatan', 'pilek', 'ping', 'punggung', 'ringan', 'sakit', 'salam', 'sape', 'saran', 'sariawan', 'saya', 'selamat', 'si', 'siang', 'siapa', 'sih', 'susah', 'terkena', 'tersumbat', 'tidak', 'tidur', 'tinggal', 'tolong', 'tugas', 'tuh', 'wah', 'ya']
# ['bye', 'cegah_demam', 'cegah_diare', 'cegah_gatal', 'cegah_influenza', 'cegah_insomnia', 'cegah_matamerah', 'cegah_pilek', 'cegah_sakitkepala', 'cegah_sakitpunggung', 'cegah_sariawan', 'demam', 'diagnobot', 'diagnobot_typo', 'diare', 'gatal', 'influenza', 'insomnia', 'lain', 'lain1', 'lain2', 'lain3', 'matamerah', 'nama', 'obat', 'pekerjaan', 'pilek', 'pilihan', 'sakitkepala', 'sakitpunggung', 'salam', 'sariawan']

# %% [markdown]
# # TRAINING DATA [Melatih Data]

# %%
# Membuat data latihan
training = []
output_empty = [0] * len(classes)

# Membuat set latihan, bag of words untuk setiap kalimat
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# Mengacak fitur dan mengubahnya menjadi np.array dengan dtype=object
random.shuffle(training)
training = np.array(training, dtype=object)

# %%
# Membuat list train_x (pola) dan train_y (niat)
train_x = list(training[:,0])
train_y = list(training[:,1])

# Membuat model neural network dengan Keras
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Mengompilasi model menggunakan SGD dengan Nesterov accelerated gradient
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Melatih model dan menyimpannya ke dalam file 'model.h5'
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist)

# Pesan konfirmasi bahwa model telah dibuat
print("Model berhasil dibuat")
# Out:
# Epoch 1/200
# 29/29 [==============================] - 1s 2ms/step - loss: 3.4677 - accuracy: 0.0621
# Epoch 2/200
# 29/29 [==============================] - 0s 2ms/step - loss: 3.3443 - accuracy: 0.0897
# Epoch 3/200
# 29/29 [==============================] - 0s 2ms/step - loss: 3.2652 - accuracy: 0.1034
# Epoch 4/200
# 29/29 [==============================] - 0s 2ms/step - loss: 3.1831 - accuracy: 0.1241
# Epoch 5/200
# 29/29 [==============================] - 0s 3ms/step - loss: 3.0458 - accuracy: 0.1448
# Epoch 6/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.8936 - accuracy: 0.2069
# Epoch 7/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.8406 - accuracy: 0.1931
# Epoch 8/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.6099 - accuracy: 0.2483
# Epoch 9/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.4979 - accuracy: 0.3103
# Epoch 10/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.4493 - accuracy: 0.2621
# Epoch 11/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.1424 - accuracy: 0.4138
# Epoch 12/200
# 29/29 [==============================] - 0s 2ms/step - loss: 2.1090 - accuracy: 0.4138
# Epoch 13/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.8783 - accuracy: 0.4207
# Epoch 14/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.8313 - accuracy: 0.4345
# Epoch 15/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.5780 - accuracy: 0.5241
# Epoch 16/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.6538 - accuracy: 0.5241
# Epoch 17/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.4168 - accuracy: 0.6207
# Epoch 18/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3468 - accuracy: 0.6069
# Epoch 19/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2859 - accuracy: 0.6000
# Epoch 20/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2173 - accuracy: 0.6000
# Epoch 21/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2057 - accuracy: 0.6207
# Epoch 22/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9979 - accuracy: 0.6690
# Epoch 23/200
# 29/29 [==============================] - 0s 2ms/step - loss: 1.1212 - accuracy: 0.6552
# Epoch 24/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9081 - accuracy: 0.7448
# Epoch 25/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9535 - accuracy: 0.7034
# Epoch 26/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9151 - accuracy: 0.7379
# Epoch 27/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9691 - accuracy: 0.6621
# Epoch 28/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.8361 - accuracy: 0.7448
# Epoch 29/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6940 - accuracy: 0.8276
# Epoch 30/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7239 - accuracy: 0.7931
# Epoch 31/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7780 - accuracy: 0.7448
# Epoch 32/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.8483
# Epoch 33/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7208 - accuracy: 0.7931
# Epoch 34/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6083 - accuracy: 0.8207
# Epoch 35/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.8345
# Epoch 36/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6381 - accuracy: 0.8207
# Epoch 37/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5479 - accuracy: 0.8552
# Epoch 38/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 0.8552
# Epoch 39/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.8759
# Epoch 40/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5719 - accuracy: 0.8138
# Epoch 41/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.8621
# Epoch 42/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.8483
# Epoch 43/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.8276
# Epoch 44/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8759
# Epoch 45/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.8483
# Epoch 46/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.8552
# Epoch 47/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.8690
# Epoch 48/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.9034
# Epoch 49/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8690
# Epoch 50/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.9241
# Epoch 51/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3708 - accuracy: 0.8897
# Epoch 52/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8621
# Epoch 53/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8759
# Epoch 54/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.9103
# Epoch 55/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.9241
# Epoch 56/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8828
# Epoch 57/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2356 - accuracy: 0.9379
# Epoch 58/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.9379
# Epoch 59/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2893 - accuracy: 0.9034
# Epoch 60/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9103
# Epoch 61/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9310
# Epoch 62/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3272 - accuracy: 0.8966
# Epoch 63/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3133 - accuracy: 0.8966
# Epoch 64/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8759
# Epoch 65/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8897
# Epoch 66/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2956 - accuracy: 0.9034
# Epoch 67/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.9103
# Epoch 68/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.